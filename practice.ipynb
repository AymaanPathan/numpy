# %% [markdown]
# 1. Convert this list into a NumPy array.
#
# 2. Count how many non-zero doses the patient took (i.e. actual medicine taken).
#
# 3. Calculate the total dose taken in a day.
#
# 4. Calculate the average dose (excluding zero doses).

# %%
import numpy as np

# %%
dosesArray = [250, 500, 500, 0, 250, 0, 500, 250]
doses = np.array((dosesArray))
doses
# Out:
# array([250, 500, 500,   0, 250,   0, 500, 250])

# %%
dosesTaken = doses[doses!=0]
dosesTaken
# Out:
# array([250, 500, 500, 250, 500, 250])

# %%
dosesTaken.sum()
# Out:
# 2250

# %%
dosesTaken.mean()
# Out:
# 375.0

# %% [markdown]
# 1. Convert this list into a NumPy array.
#
# 2. Find the median severity score.
#
# 3. Determine the standard deviation of the severity scores (how varied the scores are).
#
# 4. Identify which severity scores are greater than 3.

# %%
symptomSeverityArr =  [2, 3, 1, 5, 3, 4, 2, 1, 5, 3]
symptomSeverity = np.array((symptomSeverityArr))
symptomSeverity
# Out:
# array([2, 3, 1, 5, 3, 4, 2, 1, 5, 3])

# %%
np.median(symptomSeverity)
# Out:
# 3.0

# %%
np.std(symptomSeverity)
# Out:
# 1.374772708486752

# %%
symptomSeverity[symptomSeverity >3]
# Out:
# array([5, 4, 5])

# %% [markdown]
# 1. Convert this list into a NumPy array.
#
# 2. Calculate the sum of the quantities for the first 5 patients.
#
# 3. Determine the maximum and minimum medicine quantity prescribed.
#
# 4. Multiply the quantities by a factor of 2 (double the medicine dosage).

# %%
medicineQuantitiesArr =[5, 10, 15, 20, 25, 30, 35, 40]
medicineQuantities = np.array((medicineQuantitiesArr))
medicineQuantitiesArr
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40]

# %%
firstFive = medicineQuantities[0:5].sum()
firstFive
# Out:
# 75

# %%
medicineQuantities.max()
medicineQuantities.min()
# Out:
# 5

# %%
total = medicineQuantities *2
total
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %% [markdown]
# 1. Convert this list into a NumPy array.
#
# 2. Find the average price of the medicines.
#
# 3. Create a new array where each price is increased by 10%.
#
# 4. Determine how many medicines have a price greater than 250.

# %%
medicinePricesArr =[50, 100, 150, 200, 250, 300, 350, 400]
medicinePrices = np.array((medicinePricesArr))
medicinePrices
# Out:
# array([ 50, 100, 150, 200, 250, 300, 350, 400])

# %%
np.average(medicinePrices)
# Out:
# 225.0

# %%
medicinePrices + (medicinePrices  /10)
# Out:
# array([ 55., 110., 165., 220., 275., 330., 385., 440.])

# %%
len(medicinePrices[medicinePrices >250])
# Out:
# 3

# %% [markdown]
# 1. Convert this list into a NumPy array.
#
# 2. Calculate the mean and standard deviation of patient ages.
#
# 3. Determine the age range (difference between the maximum and minimum age).
#
# 4. Find the age group (you decide the categories) for each patient:
#
# 5. Below 30 → "Young"
#
# 6. 30–50 → "Middle-aged"
#
# 7. Above 50 → "Senior"

# %%
patientAgesArr = [22, 35, 58, 40, 61, 45, 50, 27, 38, 33]
patientAges = np.array((patientAgesArr))

# %%
mean = np.mean(patientAges)
std = np.std(patientAges)

# %%
ageRanges = patientAges.max() - patientAges.min()
print(ageRanges)
# Out:
# 39

# %%
arr = np.where(patientAges <30 ,"Young" , np.where((patientAges>=30) & (patientAges < 50), "middle","senior"))
print(arr)
# Out:
# ['Young' 'middle' 'senior' 'middle' 'senior' 'middle' 'senior' 'Young'
#  'middle' 'middle']
